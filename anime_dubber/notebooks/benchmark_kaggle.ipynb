# %% [markdown]
# # Benchmark 180s - Kaggle
# 1. Attach Kaggle Dataset with models
# 2. Run this cell: benchmark 3 backends

# %%
# !python -m pip install -q torch torchaudio faster-whisper whisperx pyannote.audio
# !git clone --recursive https://github.com/FunAudioLLM/CosyVoice.git
# !ls /kaggle/input/anime-dubber-models || echo 'upload models as dataset'

# %%
# !python benchmark.py --input /kaggle/input/test_scene.mp4 --output jobs/bench_uvr --config config.yaml
# config.yaml separation.backend=uvr_mdx -> then htdemucs -> bs_roformer
